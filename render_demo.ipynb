# %%
import os, sys
# os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import tensorflow as tf
tf.compat.v1.enable_eager_execution()

import numpy as np
import imageio
import json
import random
import time
import pprint

import matplotlib.pyplot as plt

import run_nerf

from load_llff import load_llff_data
from load_deepvoxels import load_dv_data
from load_blender import load_blender_data

# %%
basedir = './logs'
expname = 'fern_example'

config = os.path.join(basedir, expname, 'config.txt')
print('Args:')
print(open(config, 'r').read())
parser = run_nerf.config_parser()

args = parser.parse_args('--config {} --ft_path {}'.format(config, os.path.join(basedir, expname, 'model_200000.npy')))
print('loaded args')

images, poses, bds, render_poses, i_test = load_llff_data(args.datadir, args.factor, 
                                                          recenter=True, bd_factor=.75, 
                                                          spherify=args.spherify)
H, W, focal = poses[0,:3,-1].astype(np.float32)

H = int(H)
W = int(W)
hwf = [H, W, focal]

images = images.astype(np.float32)
poses = poses.astype(np.float32)

if args.no_ndc:
    near = tf.reduce_min(bds) * .9
    far = tf.reduce_max(bds) * 1.
else:
    near = 0.
    far = 1.
# Out:
# Args:
# datadir = ./data/nerf_llff_data/fern
# dataset_type = llff
# factor = 4
#
# no_batching = False
# i_embed = 0
# N_samples = 64
# N_importance = 128
# use_viewdirs = True
# lrate_decay = 250
#
# llffhold = 8
#
# N_rand = 4096
# loaded args
# Loaded image data (756, 1008, 3, 20) [ 756.         1008.          815.13158322]
# Loaded ./data/nerf_llff_data/fern 16.985296178676084 80.00209740336334
# recentered (3, 5)
# [[ 1.0000000e+00  0.0000000e+00  0.0000000e+00  1.4901161e-09]
#  [ 0.0000000e+00  1.0000000e+00 -1.8730975e-09 -9.6857544e-09]
#  [-0.0000000e+00  1.8730975e-09  1.0000000e+00  0.0000000e+00]]
# Data:
# (20, 3, 5) (20, 756, 1008, 3) (20, 2)
# HOLDOUT view is 12

# %%
# Create nerf model
_, render_kwargs_test, start, grad_vars, models = run_nerf.create_nerf(args)

bds_dict = {
    'near' : tf.cast(near, tf.float32),
    'far' : tf.cast(far, tf.float32),
}
render_kwargs_test.update(bds_dict)

print('Render kwargs:')
pprint.pprint(render_kwargs_test)


down = 4
render_kwargs_fast = {k : render_kwargs_test[k] for k in render_kwargs_test}
render_kwargs_fast['N_importance'] = 0

c2w = np.eye(4)[:3,:4].astype(np.float32) # identity pose matrix
test = run_nerf.render(H//down, W//down, focal/down, c2w=c2w, **render_kwargs_fast)
img = np.clip(test[0],0,1)
plt.imshow(img)
plt.show()
# Out:
# 2022-02-13 20:23:08.893119: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-02-13 20:23:09.004786: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-02-13 20:23:09.005672: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: dingjr
# 2022-02-13 20:23:09.005900: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: dingjr
# 2022-02-13 20:23:09.007924: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 510.47.3
# 2022-02-13 20:23:09.008652: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 510.47.3
# 2022-02-13 20:23:09.008852: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 510.47.3
# 2022-02-13 20:23:09.010421: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2022-02-13 20:23:09.025791: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300800000 Hz
# 2022-02-13 20:23:09.026878: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561fd407d1f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-02-13 20:23:09.026924: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# MODEL 63 27 <class 'int'> <class 'int'> True
# (?, 90) (?, 63) (?, 27)
# MODEL 63 27 <class 'int'> <class 'int'> True
# (?, 90) (?, 63) (?, 27)
# Found ckpts ['./logs/fern_example/model_200000.npy']
# Reloading from ./logs/fern_example/model_200000.npy
# Resetting step to 200001
# Reloading fine from ./logs/fern_example/model_fine_200000.npy
# Render kwargs:
# {'N_importance': 128,
#  'N_samples': 64,
#  'far': <tf.Tensor: id=927, shape=(), dtype=float32, numpy=1.0>,
#  'near': <tf.Tensor: id=926, shape=(), dtype=float32, numpy=0.0>,
#  'network_fine': <tensorflow.python.keras.engine.training.Model object at 0x7f857c6c84d0>,
#  'network_fn': <tensorflow.python.keras.engine.training.Model object at 0x7f857c740d50>,
#  'network_query_fn': <function create_nerf.<locals>.network_query_fn at 0x7f859e4e1dd0>,
#  'perturb': False,
#  'raw_noise_std': 0.0,
#  'use_viewdirs': True,
#  'white_bkgd': False}
# 2022-02-13 20:23:10.667289: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 528482304 exceeds 10% of system memory.
# 2022-02-13 20:23:11.399567: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 226492416 exceeds 10% of system memory.
# 2022-02-13 20:23:11.498579: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 754974720 exceeds 10% of system memory.
# 2022-02-13 20:23:12.512891: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 83623936 exceeds 10% of system memory.
# 2022-02-13 20:23:13.129531: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 74186752 exceeds 10% of system memory.

# %%
down = 8 # trade off resolution+aliasing for render speed to make this video faster
frames = []
for i, c2w in enumerate(render_poses):
    if i%8==0: print(i)
    test = run_nerf.render(H//down, W//down, focal/down, c2w=c2w[:3,:4], **render_kwargs_fast)
    frames.append((255*np.clip(test[0],0,1)).astype(np.uint8))
    
print('done, saving')
f = 'logs/fern_example/video.mp4'
imageio.mimwrite(f, frames, fps=30, quality=8)

from IPython.display import Video
Video(f, height=320)
# Out:
# 0
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64
# 72
# 80
# 88
# 96

# %%
# %matplotlib inline
from ipywidgets import interactive, widgets
import matplotlib.pyplot as plt
import numpy as np


def f(x, y, z):
    
    c2w = tf.convert_to_tensor([
        [1,0,0,x],
        [0,1,0,y],
        [0,0,1,z],
        [0,0,0,1],
    ], dtype=tf.float32)
    
    test = run_nerf.render(H//down, W//down, focal/down, c2w=c2w, **render_kwargs_fast)
    img = np.clip(test[0],0,1)
    
    plt.figure(2, figsize=(20,6))
    plt.imshow(img)
    plt.show()
    

sldr = lambda : widgets.FloatSlider(
    value=0.,
    min=-1.,
    max=1.,
    step=.01,
)

names = ['x', 'y', 'z']
    
interactive_plot = interactive(f, **{n : sldr() for n in names})
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='x', max=1.0, min=-1.0, step=0.01), FloatSlider(value…
